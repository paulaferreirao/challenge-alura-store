# %% [markdown]
# <a href="https://colab.research.google.com/github/paulaferreirao/challenge-alura-store/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# #1. Análise do faturamento

# %% [markdown]
# Nesta primeira análise, você deve calcular o faturamento total de cada loja Somando os valores da coluna Preço de cada loja para estimar o faturamento.

# %%
for faturamento_loja1 in loja:
  faturamento_loja1 = round(float(sum(loja['Preço'], 2)))
print(f' O faturamento total da loja 1 é de R${faturamento_loja1}')

for faturamento_loja2 in loja2:
  faturamento_loja2 = round(float(sum(loja2['Preço'], 2)))
print(f' O faturamento total da loja 2 é de R${faturamento_loja2}')

for faturamento_loja3 in loja3:
  faturamento_loja3 = round(float(sum(loja3['Preço'], 2)))
print(f' O faturamento total da loja 3 é de R${faturamento_loja3}')

for faturamento_loja4 in loja4:
  faturamento_loja4 = round(float(sum(loja4['Preço'], 2)))
print(f' O faturamento total da loja 4 é de R${faturamento_loja4}')
# Out:
#  O faturamento total da loja 1 é de R$1534511
#  O faturamento total da loja 2 é de R$1488461
#  O faturamento total da loja 3 é de R$1464027
#  O faturamento total da loja 4 é de R$1384500

# %%
import matplotlib.pyplot as plt

nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamento_total = [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]

fig, ax = plt.subplots(figsize=(7, 3))
plt.ticklabel_format(style='plain', axis='y')
ax.set(ylim=[1000000, 1600000], xlabel='Lojas', ylabel='Faturamento em R$', title = 'Faturamento das lojas')

plt.plot(nomes_lojas, faturamento_total)
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %% [markdown]
# Neste passo, deve calcular a quantidade de produtos vendidos por categoria em cada loja. A ideia é agrupar os dados por categoria e contar o número de vendas de cada tipo, mostrando as categoria mais populares de cada loja

# %%
qtd_produtos_loja1 = loja.groupby('Categoria do Produto').size()
print(f'A quantidade de produtos vendidos por {qtd_produtos_loja1}: ')

qtd_produtos_loja2 = loja2.groupby('Categoria do Produto').size()
print(f'A quantidade de produtos vendidos por {qtd_produtos_loja2}: ')

qtd_produtos_loja3 = loja3.groupby('Categoria do Produto').size()
print(f'A quantidade de produtos vendidos por {qtd_produtos_loja3}: ')

qtd_produtos_loja4 = loja4.groupby('Categoria do Produto').size()
print(f'A quantidade de produtos vendidos por {qtd_produtos_loja4}: ')
# Out:
# A quantidade de produtos vendidos por Categoria do Produto
# brinquedos               324
# eletrodomesticos         312
# eletronicos              448
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# moveis                   465
# utilidades domesticas    171
# dtype: int64:
# A quantidade de produtos vendidos por Categoria do Produto
# brinquedos               313
# eletrodomesticos         305
# eletronicos              422
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# moveis                   442
# utilidades domesticas    181
# dtype: int64:
# A quantidade de produtos vendidos por Categoria do Produto
# brinquedos               315
# eletrodomesticos         278
# eletronicos              451
# esporte e lazer          277
# instrumentos musicais    177
# livros                   185
# moveis                   499
# utilidades domesticas    177
# dtype: int64:
# ...

# %%
categorias = ['brinquedos', 'eletrodomesticos', 'eletronicos', 'esporte e lazer','instrumentos musicais', 'livros', 'moveis', 'utilidades domesticas']

valores_loja1 = [qtd_produtos_loja1[c] for c in categorias]
valores_loja2 = [qtd_produtos_loja2[c] for c in categorias]
valores_loja3 = [qtd_produtos_loja3[c] for c in categorias]
valores_loja4 = [qtd_produtos_loja4[c] for c in categorias]

x = np.arange(len(categorias))
largura = 0.2

fig, ax = plt.subplots(figsize=(12, 5))

ax.bar(x - 1.5*largura, valores_loja1, width=largura, label='Loja 1')
ax.bar(x - 0.5*largura, valores_loja2, width=largura, label='Loja 2')
ax.bar(x + 0.5*largura, valores_loja3, width=largura, label='Loja 3')
ax.bar(x + 1.5*largura, valores_loja4, width=largura, label='Loja 4')

ax.set_xlabel('Categorias de Produto')
ax.set_ylabel('Quantidade de Produtos Vendidos')
ax.set_title('Produtos Vendidos por Categoria em Cada Loja')
ax.set_xticks(x)
ax.set_xticklabels(categorias, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# Lista com os dados e nomes das lojas
dados_lojas = [
    (qtd_produtos_loja1, 'Loja 1'),
    (qtd_produtos_loja2, 'Loja 2'),
    (qtd_produtos_loja3, 'Loja 3'),
    (qtd_produtos_loja4, 'Loja 4')
]

for dados, nome in dados_lojas:
    plt.figure(figsize=(10, 4))
    plt.bar(dados.index, dados.values)
    plt.title(f'Quantidade de Produtos Vendidos - {nome}')
    plt.xlabel('Categoria do Produto')
    plt.ylabel('Quantidade Vendida')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# Neste passo, vamos calcular a média das avaliações dos clientes para cada loja. O objetivo é entender a satisfação dos clientes com os produtos vendidos.

# %%
media_avaliacao_loja1 = round(float(loja['Avaliação da compra'].sum()/len(loja['Avaliação da compra'])), 2)
media_avaliacao_loja2 = round(float(loja2['Avaliação da compra'].sum()/len(loja2['Avaliação da compra'])), 2)
media_avaliacao_loja3 = round(float(loja3['Avaliação da compra'].sum()/len(loja3['Avaliação da compra'])), 2)
media_avaliacao_loja4 = round(float(loja4['Avaliação da compra'].sum()/len(loja4['Avaliação da compra'])), 2)

media_avaliacoes_lojas = [media_avaliacao_loja1, media_avaliacao_loja2, media_avaliacao_loja3, media_avaliacao_loja4]

print(f' A média de avaliação para cada loja foi de: Loja 1 - {media_avaliacao_loja1}, Loja 2 - {media_avaliacao_loja2}, Loja 3 - {media_avaliacao_loja3}, Loja 4 - {media_avaliacao_loja4}')
# Out:
#  A média de avaliação para cada loja foi de: Loja 1 - 3.98, Loja 2 - 4.04, Loja 3 - 4.05, Loja 4 - 4.0

# %%
plt.figure(figsize=(5, 5))
bar_colors=['tab:blue','tab:orange', 'tab:green','tab:gray']
plt.bar(nomes_lojas, media_avaliacoes_lojas,color=bar_colors)
plt.plot(nomes_lojas, media_avaliacoes_lojas, marker='o', linestyle='--', color='red', label='Media das Avaliações')

for i, valor in enumerate(media_avaliacoes_lojas):
    plt.text(i, valor + 0.02, f"{valor:.2f}", ha='center', va='bottom')

plt.ylim(3.5, 4.5)

plt.title("Avaliação das Lojas")
plt.xlabel("Lojas")
plt.ylabel("Avaliação(1-5)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# Neste passo, deve identificar quais produtos foram os mais vendidos e os menos vendidos em cada loja.  Ao final, visualize os resultados de forma que fique claro quais produtos se destacaram nas vendas de cada loja.

# %%
produtos_vendidos_loja1 = loja['Produto'].value_counts()
mais_vendidos_loja1 = produtos_vendidos_loja1.head(5)
menos_vendidos_loja1 = produtos_vendidos_loja1.tail(5)

vendas_loja1 = [mais_vendidos_loja1, menos_vendidos_loja1]

print("5 Produtos mais vendidos na Loja 1:")
print(mais_vendidos_loja1)

print("\n5 Produtos menos vendidos na Loja 1:")
print(menos_vendidos_loja1)

# 5 mais vendidos - Loja 1

fig, ax = plt.subplots()
ax.pie(mais_vendidos_loja1.values, labels=mais_vendidos_loja1.index, autopct='%1.1f%%')
ax.set_title('5 Produtos mais vendidos - Loja 1')

# 5 menos vendidos - Loja 1

fig, ax = plt.subplots()
ax.pie(menos_vendidos_loja1.values, labels=menos_vendidos_loja1.index, autopct='%1.1f%%')
ax.set_title('5 Produtos menos vendidos - Loja 1')
# Out:
# 5 Produtos mais vendidos na Loja 1:
# Produto
# Micro-ondas           60
# TV Led UHD 4K         60
# Guarda roupas         60
# Secadora de roupas    58
# Cômoda                56
# Name: count, dtype: int64
#
# 5 Produtos menos vendidos na Loja 1:
# Produto
# Ciência de dados com python    39
# Pandeiro                       36
# Panela de pressão              35
# Headset                        33
# Celular ABXY                   33
# Name: count, dtype: int64
# Text(0.5, 1.0, '5 Produtos menos vendidos - Loja 1')

# %%
produtos_vendidos_loja2 = loja2['Produto'].value_counts()
mais_vendidos_loja2 = produtos_vendidos_loja2.head(5)
menos_vendidos_loja2 = produtos_vendidos_loja2.tail(5)

print("5 Produtos mais vendidos na Loja 2:")
print(mais_vendidos_loja2)

print("\n5 Produtos menos vendidos na Loja :")
print(menos_vendidos_loja2)

# 5 mais vendidos - Loja 2

fig, ax = plt.subplots()
ax.pie(mais_vendidos_loja2.values, labels=mais_vendidos_loja2.index, autopct='%1.1f%%')
ax.set_title('5 Produtos mais vendidos - Loja 2')

# 5 menos vendidos - Loja 1

fig, ax = plt.subplots()
ax.pie(menos_vendidos_loja2.values, labels=menos_vendidos_loja2.index, autopct='%1.1f%%')
ax.set_title('5 Produtos menos vendidos - Loja 2')
# Out:
# 5 Produtos mais vendidos na Loja 2:
# Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
# Name: count, dtype: int64
#
# 5 Produtos menos vendidos na Loja :
# Produto
# Fone de ouvido       37
# Poltrona             35
# Mesa de jantar       34
# Impressora           34
# Jogo de tabuleiro    32
# Name: count, dtype: int64
# Text(0.5, 1.0, '5 Produtos menos vendidos - Loja 2')

# %%
produtos_vendidos_loja3 = loja3['Produto'].value_counts()
mais_vendidos_loja3 = produtos_vendidos_loja3.head(5)
menos_vendidos_loja3 = produtos_vendidos_loja3.tail(5)

print("5 Produtos mais vendidos na Loja 3:")
print(mais_vendidos_loja3)

print("\n5 Produtos menos vendidos na Loja 3:")
print(menos_vendidos_loja3)

# 5 mais vendidos - Loja 3

fig, ax = plt.subplots()
ax.pie(mais_vendidos_loja3.values, labels=mais_vendidos_loja3.index, autopct='%1.1f%%')
ax.set_title('5 Produtos mais vendidos - Loja 3')

# 5 menos vendidos - Loja 3

fig, ax = plt.subplots()
ax.pie(menos_vendidos_loja3.values, labels=menos_vendidos_loja3.index, autopct='%1.1f%%')
ax.set_title('5 Produtos menos vendidos - Loja 3')
# Out:
# 5 Produtos mais vendidos na Loja 3:
# Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# Jogo de panelas    55
# Cômoda             55
# Name: count, dtype: int64
#
# 5 Produtos menos vendidos na Loja 3:
# Produto
# Guitarra            38
# Jogo de copos       36
# Mochila             36
# Micro-ondas         36
# Blocos de montar    35
# Name: count, dtype: int64
# Text(0.5, 1.0, '5 Produtos menos vendidos - Loja 3')

# %%
produtos_vendidos_loja4 = loja4['Produto'].value_counts()
mais_vendidos_loja4 = produtos_vendidos_loja4.head(5)
menos_vendidos_loja4 = produtos_vendidos_loja4.tail(5)

print("5 Produtos mais vendidos na Loja 4:")
print(mais_vendidos_loja4)

print("\n5 Produtos menos vendidos na Loja 4:")
print(menos_vendidos_loja4)

# 5 mais vendidos - Loja 1

fig, ax = plt.subplots()
ax.pie(mais_vendidos_loja4.values, labels=mais_vendidos_loja4.index, autopct='%1.1f%%')
ax.set_title('5 Produtos mais vendidos - Loja 4')

# 5 menos vendidos - Loja 1

fig, ax = plt.subplots()
ax.pie(menos_vendidos_loja4.values, labels=menos_vendidos_loja4.index, autopct='%1.1f%%')
ax.set_title('5 Produtos menos vendidos - Loja 4')
# Out:
# 5 Produtos mais vendidos na Loja 4:
# Produto
# Cama box                    62
# Faqueiro                    59
# Dashboards com Power BI     56
# Cama king                   56
# Carrinho controle remoto    55
# Name: count, dtype: int64
#
# 5 Produtos menos vendidos na Loja 4:
# Produto
# Geladeira                      38
# Ciência de dados com python    38
# Violão                         37
# Guarda roupas                  34
# Guitarra                       33
# Name: count, dtype: int64
# Text(0.5, 1.0, '5 Produtos menos vendidos - Loja 4')

# %% [markdown]
# # 5. Frete Médio por Loja

# %% [markdown]
# Neste passo, vamos calcular o custo médio de frete para cada loja. O objetivo é entender quanto, em média, está sendo gasto com frete para cada uma das lojas.

# %%
frete_medio_loja1 = round(float(loja['Frete'].sum()/len(loja['Frete'])), 2)
print(f'O frete médio da loja 1 é de {frete_medio_loja1}')

frete_medio_loja2 = round(float(loja2['Frete'].sum()/len(loja2['Frete'])), 2)
print(f'O frete médio da loja 2 é de {frete_medio_loja2}')

frete_medio_loja3 = round(float(loja3['Frete'].sum()/len(loja3['Frete'])), 2)
print(f'O frete médio da loja 3 é de {frete_medio_loja3}')

frete_medio_loja4 = round(float(loja4['Frete'].sum()/len(loja4['Frete'])), 2)
print(f'O frete médio da loja 4 é de {frete_medio_loja4}')

frete_lojas = [frete_medio_loja1, frete_medio_loja2, frete_medio_loja3, frete_medio_loja4]
# Out:
# O frete médio da loja 1 é de 34.69
# O frete médio da loja 2 é de 33.62
# O frete médio da loja 3 é de 33.07
# O frete médio da loja 4 é de 31.28

# %%
plt.figure(figsize=(5, 5))
bar_colors=['tab:blue','tab:orange', 'tab:green','tab:gray']
plt.bar(nomes_lojas, frete_lojas,color=bar_colors)
plt.plot(nomes_lojas, frete_lojas, marker='o', linestyle='--', color='red', label='Frete em R$')

for i, valor in enumerate(frete_lojas):
    plt.text(i, valor + 0.02, f"{valor:.2f}", ha='center', va='bottom')

plt.ylim(30, 35)

plt.title("Frete Médio das Lojas")
plt.xlabel("Lojas")
plt.ylabel("Frete(30-35)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Relatório Final
#
# ## Faturamento total das lojas.
#
# De acordo com a análise, observa-se que o maior valor de faturamento total é o da loja 1, com R$1.534.511.
#
# Os faturamentos das lojas 2 e 3 apresentam valores aproximados, com R$1.488.461 e R$1.464.027, respectivamente.
#
# O menor faturamento total é o da loja 4 é de R$1.384.500.
#
# ## Categorias de produtos mais e menos vendidas.
#
# Todas as lojas apresentam as mesmas categorias de produtos, sendo brinquedos, eletrodomésticos, eletrônicos, esporte e lazer, instrumentos musicais, livros, móveis e utilidades domésticas.
#
# As lojas 1, 2 e 3 possuem um padrão de categorias eletrônicos apresentando a maior quantidade de vendas atrelada a categoria eletrônicos e a menor quantidade de vendas a categoria utilidades domésticas.
#
# Porém, a loja 4 apresenta a categoria mais vendido da loja 1  é móveis, com 480 vendas, enquanto a menos vendida é livros, com 170 vendas.
#
# ## Média das avaliações de clientes por loja.
#
# A média de avaliação para cada loja foi de: Loja 1 - 3.98, Loja 2 - 4.04, Loja 3 - 4.05, Loja 4 - 4.0.
#
# A loja com melhor avaliação foi a loja 3 e a loja 1 a pior avaliação.
#
# ## Produtos mais e menos vendidos.
#
# Loja 1: mais vendidos – Micro-ondas, TV LED UHD 4K, Guarda-roupas (60 unidades); menos vendido – Celular ABXY (33 unidades).
#
# Loja 2: mais vendido – Iniciando em Programação (65 unidades); menos vendido – Jogo de tabuleiro (32 unidades).
#
# Loja 3: mais vendido – Kit Banquetas (57 unidades); menos vendido – Blocos de Montar (35 unidades).
#
# Loja 4: mais vendido – Cama Box (62 unidades); menos vendido – Guitarra (33 unidades).
#
# ## Frete médio de cada loja.
#
# A loja com o maior frete é a loja 1, com R$34.69. A loja com menor frete é a loja 4 com R$31.28
#
# O frete médio da loja 2 e 3 apresentam valores parecidos, de R$33.62 e R$33.07, respectivamente.
#
# ## Conclusão
#
# A loja 1 apresenta maior valor de faturamento total e variedade de produtos vendidos. No entanto, apresenta maior frete atrelado aos produtos e a pior média de avaliação.
#
# As lojas 2 e 3 apresentam resultados similares em todos os parâmetros. São estáveis, com um bom equilíbrio entre faturamento, avaliação e logística.
#
# Por outro lado, a loja 4 se mostra como uma das melhores avaliações e menor faturamento. Também apresenta um frete mais barato, o que é positivo, mas não compensa o fraco desempenho de vendas.
#
# Por fim, recomenda-se ao senhor João a venda da loja 4 por apresentar o menor faturamento total entre as quatro lojas da rede, uma performance de vendas menos alinhada com o padrão das demais lojas e uma menor eficiência geral. A venda dessa unidade pode reduzir custos e liberar recursos para o novo empreendimento, com o menor impacto possível sobre o desempenho da rede.
